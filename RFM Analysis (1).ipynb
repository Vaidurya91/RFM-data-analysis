# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel (r'C:\Users\Vaidu\Desktop\OnlineRetail.xlsx')
df.head()
df1=df

# %%
#Dataset 
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# ...

# %%
df1.Country.nunique()
# Out:
# 38

# %%
#The 38 unique countries are as follows:
df1.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
customer_country=df1[['Country','CustomerID']].drop_duplicates()
customer_country
customer_country.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID', ascending=False)
# Out:
#                  Country  CustomerID
# 36        United Kingdom        3921
# 14               Germany          94
# 13                France          87
# 31                 Spain          30
# 3                Belgium          25
# 33           Switzerland          21
# 27              Portugal          19
# 19                 Italy          14
# 12               Finland          12
# 1                Austria          11
# 25                Norway          10
# 24           Netherlands           9
# 0              Australia           9
# 6        Channel Islands           9
# 9                Denmark           9
# 7                 Cyprus           8
# 32                Sweden           8
# 20                 Japan           8
# 26                Poland           6
# 34                   USA           4
# 5                 Canada           4
# 37           Unspecified           4
# 15                Greece           4
# 10                  EIRE           3
# ...

# %%
#Restrict the data to United Kingdom only
df1=df1.loc[df1['Country']=='United Kingdom']

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# ...

# %%
#Check whether there are missing values in each column
df1.isnull().sum(axis=0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Revenue             0
# Quartile            0
# Unnamed: 10    541909
# Unnamed: 11    541905
# Unnamed: 12    541907
# dtype: int64

# %%
#Remove the missing values in CustomerID column
df1=df1[pd.notnull(df1['CustomerID'])]

# %%
df1.Quantity.min()
# Out:
# -80995

# %%
#Remove the negative values in quantity column
df1=df1[(df1['Quantity']>0)]
df1.shape
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531285 entries, 0 to 541908
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    531285 non-null  object
#  1   StockCode    531285 non-null  object
#  2   Description  530693 non-null  object
#  3   Quantity     531285 non-null  int64
#  4   InvoiceDate  531285 non-null  datetime64[ns]
#  5   UnitPrice    531285 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      531285 non-null  object
#  8   Revenue      531285 non-null  float64
#  9   Quartile     531285 non-null  object
#  10  Unnamed: 10  0 non-null       float64
#  11  Unnamed: 11  4 non-null       object
#  12  Unnamed: 12  2 non-null       float64
#  13  TotalPrice   531285 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(6)
# memory usage: 60.8+ MB

# %%
#Check unique value for each column
def unique_counts(df1):
    for i in df1.columns:
        count=df1[i].nunique()
        print(i,":",count)
unique_counts(df1)
# Out:
# InvoiceNo : 20728
# StockCode : 3941
# Description : 4077
# Quantity : 393
# InvoiceDate : 19052
# UnitPrice : 1293
# CustomerID : 4339
# Country : 38
# Revenue : 4908
# Quartile : 4
# Unnamed: 10 : 0
# Unnamed: 11 : 4
# Unnamed: 12 : 2

# %%
#Calculate Total Price
df1['TotalPrice']=df1['Quantity']*df1['UnitPrice']

# %%
#Find out first and last order dates in the data
df1['InvoiceDate'].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
df1['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
import datetime as dt
NOW=dt.datetime(2011,12,10)
df1['InvoiceDate']=pd.to_datetime(df1['InvoiceDate'])

# %%
#Create a RFM Table
rfmTable = df1.groupby('CustomerID').agg({'InvoiceDate': lambda x: (NOW - x.max()).days, 'InvoiceNo': lambda x: len(x), 'TotalPrice': lambda x: x.sum()})
rfmTable['InvoiceDate'] = rfmTable['InvoiceDate'].astype(int)
rfmTable.rename(columns={'InvoiceDate': 'recency', 
                         'InvoiceNo': 'frequency', 
                         'TotalPrice': 'monetary_value'}, inplace=True)

# %%
#Calculate RFM metrics for each customer
rfmTable.head()
# Out:
#             recency  frequency  monetary_value
# CustomerID
# 12346.0         325          1        77183.60
# 12347.0           2        182         4310.00
# 12348.0          75         31         1797.24
# 12349.0          18         73         1757.55
# 12350.0         310         17          334.40

# %%
#Split metrics in segments by using quartiles
quantiles=rfmTable.quantile(q=[0.25,0.5,0.75])
quantiles=quantiles.to_dict()

# %%
#Created segmented RFM table
segmented_rfm=rfmTable

# %%
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
#Add segment tables to newly created segmented RFM table
segmented_rfm['r_quartile'] = segmented_rfm['recency'].apply(RScore, args=('recency',quantiles,))
segmented_rfm['f_quartile'] = segmented_rfm['frequency'].apply(FMScore, args=('frequency',quantiles,))
segmented_rfm['m_quartile'] = segmented_rfm['monetary_value'].apply(FMScore, args=('monetary_value',quantiles,))
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           4           4
# 12347.0           2        182         4310.00           1           1
# 12348.0          75         31         1797.24           3           3
# 12349.0          18         73         1757.55           2           2
# 12350.0         310         17          334.40           4           4
#
#             m_quartile
# CustomerID
# 12346.0              1
# 12347.0              1
# 12348.0              1
# 12349.0              1
# 12350.0              3

# %%
#Add new column to combine RFM scores
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str) + segmented_rfm.f_quartile.map(str) + segmented_rfm.m_quartile.map(str)
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           4           4
# 12347.0           2        182         4310.00           1           1
# 12348.0          75         31         1797.24           3           3
# 12349.0          18         73         1757.55           2           2
# 12350.0         310         17          334.40           4           4
#
#             m_quartile RFMScore
# CustomerID
# 12346.0              1      441
# 12347.0              1      111
# 12348.0              1      331
# 12349.0              1      221
# 12350.0              3      443

# %%
# Top 10 best customers
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 14646.0           1       2080       280206.02           1           1
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 14911.0           1       5677       143825.06           1           1
# 14156.0           9       1400       117379.63           1           1
# 17511.0           2        963        91062.38           1           1
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
#
#             m_quartile RFMScore
# CustomerID
# 14646.0              1      111
# 18102.0              1      111
# 17450.0              1      111
# ...
